# %%
from pathlib import Path

import pandas as pd
import numpy as np

from gtfs_tools.gtfs import GtfsDataset
from gtfs_tools.utils.gtfs import get_route_types_table

# %%
pth = r'D:\projects\gtfs-tools\data\raw\gtfs_olympia\mdb_source_id=268'

# %%
gtfs = GtfsDataset(pth)

gtfs
# Out:
# ERROR:root:Cannot locate any required files in the GTFS dataset mdb_source_id=268.
# GtfsDataset: D:\projects\gtfs-tools\data\raw\gtfs_olympia\mdb_source_id=268

# %%
gtfs.validate()
# Out:
# ERROR:root:Cannot locate any required files in the GTFS dataset mdb_source_id=268.
# False

# %%
gtfs.trips.data
# Out:
#      route_id                       trip_id                 service_id  \
# 0     SNDR_TL               1500-Spring2023   WD_SNDR_20230320_Weekday
# 1     SNDR_TL                         1500R            REDUCED_WD_SNDR
# 2     SNDR_TL               1501-Spring2023   WD_SNDR_20230320_Weekday
# 3     SNDR_TL               1502-Spring2023   WD_SNDR_20230320_Weekday
# 4     SNDR_TL               1503-Spring2023   WD_SNDR_20230320_Weekday
# ...       ...                           ...                        ...
# 3490    TLINE  TLINE_2023_HTLE12_Weekday_95  TLINE_2023_HTLE12_Weekday
# 3491    TLINE  TLINE_2023_HTLE12_Weekday_96  TLINE_2023_HTLE12_Weekday
# 3492    TLINE  TLINE_2023_HTLE12_Weekday_97  TLINE_2023_HTLE12_Weekday
# 3493    TLINE  TLINE_2023_HTLE12_Weekday_98  TLINE_2023_HTLE12_Weekday
# 3494    TLINE  TLINE_2023_HTLE12_Weekday_99  TLINE_2023_HTLE12_Weekday
#
#      trip_short_name        trip_headsign  direction_id     block_id  \
# 0               1500  King Street Station             1          NaN
# 1               1500  King Street Station             1          NaN
# 2               1501  Tacoma Dome Station             0          NaN
# 3               1502  King Street Station             1          NaN
# 4               1503  Tacoma Dome Station             0          NaN
# ...              ...                  ...           ...          ...
# 3490             NaN          Tacoma Dome             1  TLINE_Trn-3
# 3491             NaN          Tacoma Dome             1  TLINE_Trn-4
# 3492             NaN          Tacoma Dome             1  TLINE_Trn-1
# 3493             NaN          Tacoma Dome             1  TLINE_Trn-3
# 3494             NaN          Tacoma Dome             1  TLINE_Trn-4
#
#               shape_id  wheelchair_accessible  drt_advance_book_min  \
# 0     SNDR_TL_NBLW_shp                      1                   0.0
# 1     SNDR_TL_NBLW_shp                      1                   0.0
# 2       SNDR_TL_SB_shp                      1                   0.0
# 3     SNDR_TL_NBLW_shp                      1                   0.0
# 4       SNDR_TL_SB_shp                      1                   0.0
# ...                ...                    ...                   ...
# 3490           T25:T01                      1                   0.0
# 3491           T25:T01                      1                   0.0
# 3492           T25:T01                      1                   0.0
# 3493           T25:T01                      1                   0.0
# 3494           T25:T01                      1                   0.0
#
#       bikes_allowed  peak_offpeak  boarding_type
# 0                 1             0              0
# 1                 1             0              0
# 2                 1             0              0
# 3                 1             0              0
# 4                 1             0              0
# ...             ...           ...            ...
# 3490              1             0              0
# 3491              1             0              0
# 3492              1             0              0
# 3493              1             0              0
# 3494              1             0              0
#
# [3495 rows x 13 columns]
