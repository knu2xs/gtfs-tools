# %%
from pathlib import Path

import pandas as pd

# %%
assets_pth = Path(r'D:\projects\gtfs-tools\docsrc\mkdocs\assets')

# %%
pd.options.display.float_format = '${:,.2f}'.format

# %%
for csv_pth in assets_pth.glob('*.txt'):
    csv_df = pd.read_csv(csv_pth, dtype='string')
    tbl_md = csv_df.to_markdown(index=False)
    print(tbl_md)
# Out:
# | service_id                   |   monday |   tuesday |   wednesday |   thursday |   friday |   saturday |   sunday |   start_date |   end_date |
# |:-----------------------------|---------:|----------:|------------:|-----------:|---------:|-----------:|---------:|-------------:|-----------:|
# | AFA23GEN-1038-Sunday-00      |        0 |         0 |           0 |          0 |        0 |          0 |        1 |     20231217 |   20240616 |
# | AFA23GEN-1039-Saturday-00    |        0 |         0 |           0 |          0 |        0 |          1 |        0 |     20231223 |   20240622 |
# | AFA23GEN-1092-Weekday-00_C45 |        1 |         1 |           1 |          1 |        1 |          0 |        0 |     20231218 |   20240621 |
# |   service_id |     date |   exception_type |
# |-------------:|---------:|-----------------:|
# |            1 | 20240210 |                1 |
# |            1 | 20240211 |                1 |
# |            1 | 20240217 |                1 |
# ...

# %%
from gtfs_tools.gtfs import GtfsDataset

# %%
gtfs_pth = Path(r"\\DevBA00007\data\gtfs_publishing\scratch\valley_metro_az\googletransit.zip")

gtfs_pth
# Out:
# WindowsPath('//DevBA00007/data/gtfs_publishing/scratch/valley_metro_az/googletransit.zip')

# %%
gtfs = GtfsDataset(gtfs_pth)

gtfs
# Out:
# GtfsDataset: C:\Users\joel5174\AppData\Local\Temp\tmphdd7yflo

# %%
stops_sedf = (
    gtfs.stops.sedf
    .merge(gtfs.lookup_stop_agency, on='stop_id', how='left')
    .merge(gtfs.agency.data, on='agency_id', how='left')
)



stops_sedf
# Out:
#          stop_id  stop_code              stop_name  \
# 0            100 $16,619.00      Bell Rd & 44th St
# 1           1002 $15,234.00     Alice Av & 66th Dr
# 2           1003 $13,532.00   Atlanta Av & 11th Av
# 3           1004 $14,926.00  Baseline Rd & 19th Av
# 4           1005 $11,503.00  Baseline Rd & 35th Av
# ...          ...        ...                    ...
# 8085  place_BUPR        NaN            Buckeye PNR
# 8086  place_GYPR        NaN           Goodyear PNR
# 8087  place_GYPR        NaN           Goodyear PNR
# 8088  place_SUPR        NaN           Surprise PNR
# 8089  place_SUPR        NaN           Surprise PNR
#
#                         stop_desc  stop_lat  stop_lon zone_id  stop_url  \
# 0         EB Bell Rd & FS 44th St    $33.64  $-111.99    <NA>       NaN
# 1        EB Alice Av & FS 66th Dr    $33.56  $-112.20    <NA>       NaN
# 2      EB Atlanta Av & FS 11th Av    $33.40  $-112.09    <NA>       NaN
# ...
